# %%
# !pip3 install pandas

# %%
import pandas as pd

# %%
emp_data = [
    ["001","101","John Doe","30","Male","50000","2015-01-01"],
    ["002","101","Jane Smith","25","Female","45000","2016-02-15"],
    ["003","102","Bob Brown","35","Male","55000","2014-05-01"],
    ["004","102","Alice Lee","28","Female","48000","2017-09-30"],
    ["005","103","Jack Chan","40","Male","60000","2013-04-01"],
    ["006","103","Jill Wong","32","Female","52000","2018-07-01"],
    ["007","101","James Johnson","42","Male","70000","2012-03-15"],
    ["008","102","Kate Kim","29","Female","51000","2019-10-01"],
    ["009","103","Tom Tan","33","Male","58000","2016-06-01"],
    ["010","104","Lisa Lee","27","Female","47000","2018-08-01"],
    ["011","104","David Park","38","Male","65000","2015-11-01"],
    ["012","105","Susan Chen","31","Female","54000","2017-02-15"],
    ["013","106","Brian Kim","45","Male","75000","2011-07-01"],
    ["014","107","Emily Lee","26","Female","46000","2019-01-01"],
    ["015","106","Michael Lee","37","Male","63000","2014-09-30"],
    ["016","107","Kelly Zhang","30","Female","49000","2018-04-01"],
    ["017","105","George Wang","34","Male","57000","2016-03-15"],
    ["018","104","Nancy Liu","29","Female","50000","2017-06-01"],
    ["019","103","Steven Chen","36","Male","62000","2015-08-01"],
    ["020","102","Grace Kim","32","Female","53000","2018-11-01"]
]

emp_schema = "employee_id , department_id , name , age , gender , salary , hire_date"

# %%
# create DataFrame
emp_df = pd.DataFrame(emp_data, columns=emp_schema.split(", "))

# %%
emp_df.head()

# %%
emp_df.head(10)
emp_df.tail(5)

# %%
emp_data =   [
    ["001","101","John Doe","30","Male","50000","2015-01-01"],
    ["002","101","Jane Smith","25","Female","45000","2016-02-15"],
    ["003","102","Bob Brown","35","Male","55000","2014-05-01"]
    ]
emp_schema = "employee_id, department_id, name, age, gender, salary, hire_date"

# %%
# read csv file into DataFrame
df1 = pd.read_csv("cities.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302868 entries, 0 to 2302867
# Data columns (total 5 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   city_id    int64
#  1   city       object
#  2   state      object
#  3   state_abv  object
#  4   country    object
# dtypes: int64(1), object(4)
# memory usage: 87.8+ MB

# %%
df1[df1["city_id"] == "324732552"]
df1["city_id"].count()
# Out:
# np.int64(2302868)

# %%
df2= pd.read_csv("empdb.csv")

# %%
df2.info()

# %%
# df2[df2["name"] == "Anita"]
# sum of salaries
df2["salary"].count()
df2.shape

# query to find employees with salary greater than 50000
high_salary_employees = df2[df2["salary"] > 50000]

df2["name"].astype(str)
df2.info()

# %%
df2.head()

# %%
# read pdf file into DataFrame
df3 = pd.read_pdf("CapstoneProject.pdf")

# %%
import numpy as np

np.loadtxt("empdb.csv", delimiter=",", skiprows=1, dtype=str)

# %%
df2.info()

# %%
df3 = df2[df2["salary"] > 50000]

# %%
print(df3)

# %%
df3.to_csv("high_salary_employees.csv", index=False)

# %%
df_json = pd.read_json("emp.json")

# %%
print(df_json)
